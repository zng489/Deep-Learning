# %%
import tensorflow as tf

# %%
#!pip install tensorflow==2.3.0

# %%
scalar = tf.constant(7 )
scalar
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=7>

# %%
scalar.ndim
# Out:
# 0

# %%
vector = tf.constant([10,10])
vector
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e29ae06ac49a> in <module>
# ----> 1 vector = tf.constant([10,10])
#       2 vector
#
# NameError: name 'tf' is not defined

# %%
vector.ndim
# Out:
# 1

# %%
#####################################################################################################
#####################################################################################################
#####################################################################################################

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create features
X = np.array([-7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0])

# Create labels
y = np.array([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0 , 24.0])

# Visualize it
plt.scatter(x, y);

# %%
X + 10
# Out:
# array([ 3.,  6.,  9., 12., 15., 18., 21., 24.])

# %%
y == X + 10
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True])

# %%
# Input and output shapes

house_info = tf.constant(['bedroom','bathroom', 'garage'])
house_price = tf.constant([939700])

house_info, house_price
# Out:
# (<tf.Tensor: shape=(3,), dtype=string, numpy=array([b'bedroom', b'bathroom', b'garage'], dtype=object)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([939700])>)

# %%
input_shape = X.shape
output_shape = y.shape

input_shape, output_shape
# Out:
# ((8,), (8,))

# %%
X[0], y[0]
# Out:
# (-7.0, 3.0)

# %%
input_shape = X[0].shape
output_shape = y[0].shape

input_shape, output_shape
# Out:
# ((), ())

# %%
X[0].ndim
# Out:
# 0

# %%
# Turn our numpy arryas into tensors

X = tf.constant(X)

y = tf.constant(y)

X,y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float64, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.])>,
#  <tf.Tensor: shape=(8,), dtype=float64, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.])>)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('plas.csv')
df
# Out:
#       Catalyst  Entry Molar ratio   T   theory_Mn  Yield     Mn    Mw     DM  \
# 0   BMI.In2Cl7      1       1-500  130    1512.00      98  2450  3706  1.510
# 1   BMI.In2Cl7      2       1-800  130     872.00      98  1498  2207  1.470
# 2   BMI.In2Cl7      3       1-650  120     726.54      98  1571  1805  1.140
# 3   BMI.In2Cl7      4       1-650  120     972.50      97  1497  2070  1.380
# 4   BMI.In2Cl7      5       1-650  120     825.58      97  1515  2130  1.400
# 5   BMI.In2Cl7      6       1-500  110     872.01      86  1196  1884  1.570
# 6   BMI.In2Cl7      7       1-800  110     625.84      89   818  1347  1.110
# 7   BMI.Cu2Cl3      8       1-500  130    1872.00      98  2172  2426  1.110
# 8   BMI.Cu2Cl3      9       1-800  130    1512.00      95  1625  2745  1.680
# 9   BMI.Cu2Cl3     10       1-650  120    1872.00      88  1105  1617  1.460
# 10  BMI.Cu2Cl3     11       1-650  120     972.00      87   810  1603  1.970
# 11  BMI.Cu2Cl3     12       1-650  120    1095.00      89  1270  2020  1.590
# 12  BMI.Cu2Cl3     13       1-500  110    1272.00      86   987  1167  1.180
# 13  BMI.Cu2Cl3     14       1-800  110     672.00      81   509   614  1.200
# 14  BMI.Sn2Cl5     15       1-500  130    2400.00      98  2115  2654  1.250
# 15  BMI.Sn2Cl5     16       1-800  130    1100.00      97  1671  2901  1.730
# 16  BMI.Sn2Cl5     17       1-650  120     110.57      95  2002  2514  1.255
# 17  BMI.Sn2Cl5     18       1-650  120     972.00      95  1275  1741  1.360
# 18  BMI.Sn2Cl5     19       1-650  120     972.00      96  2310  2532  1.100
# 19  BMI.Sn2Cl5     20       1-500  110     625.84      96   803   917  1.140
# 20  BMI.Sn2Cl5     21       1-800  110     522.00      95   841  1223  1.450
# 21        DBTL     22       1-500  130     348.92      98   323   385  1.190
# 22        DBTL     23       1-800  130     290.18      98   300   352  1.170
# 23        DBTL     24       1-650  120     192.30      97   249   257  1.030
# 24        DBTL     25       1-650  120     216.00      97   274   297  1.080
# 25        DBTL     26       1-650  120     204.00      98   271   283  1.040
# 26        DBTL     27       1-500  110     432.00      98   275   284  1.030
# 27        DBTL     28       1-800  110     338.66      98   256   258  1.000
#
#     DSC  ...  time  mn_110  mw_110   DPI_110  mn_120  mw_120   DPI_120  \
# 0   NaN  ...   2.0   226.0   233.0  1.030973   281.0   784.0  2.790036
# 1   NaN  ...   4.0   254.0   281.0  1.106299   313.0   365.0  1.166134
# 2   NaN  ...   6.0   221.0   231.0  1.045249   289.0   323.0  1.117647
# 3   NaN  ...   8.0   275.0   342.0  1.243636   308.0   390.0  1.266234
# 4   NaN  ...  10.0   313.0   365.0  1.166134   422.0   653.0  1.547393
# 5   NaN  ...  12.0   289.0   323.0  1.117647   344.0   757.0  2.200581
# 6   NaN  ...  14.0   308.0   390.0  1.266234   354.0   784.0  2.214689
# 7   NaN  ...  16.0   332.0   471.0  1.418675   527.0   951.0  1.804554
# 8   NaN  ...  18.0   327.0   466.0  1.425076   420.0  1113.0  2.650000
# 9   NaN  ...  20.0   321.0   451.0  1.404984   468.0  1130.0  2.414530
# 10  NaN  ...  22.0   339.0   423.0  1.247788   453.0  1144.0  2.525386
# 11  NaN  ...  24.0   328.0   393.0  1.198171   706.0  1328.0  1.881020
# 12  NaN  ...   NaN     NaN     NaN       NaN     NaN     NaN       NaN
# 13  NaN  ...   NaN     NaN     NaN       NaN     NaN     NaN       NaN
# 14  NaN  ...   NaN     NaN     NaN       NaN     NaN     NaN       NaN
# 15  NaN  ...   NaN     NaN     NaN       NaN     NaN     NaN       NaN
# 16  NaN  ...   NaN     NaN     NaN       NaN     NaN     NaN       NaN
# 17  NaN  ...   NaN     NaN     NaN       NaN     NaN     NaN       NaN
# 18  NaN  ...   NaN     NaN     NaN       NaN     NaN     NaN       NaN
# 19  NaN  ...   NaN     NaN     NaN       NaN     NaN     NaN       NaN
# 20  NaN  ...   NaN     NaN     NaN       NaN     NaN     NaN       NaN
# 21  NaN  ...   NaN     NaN     NaN       NaN     NaN     NaN       NaN
# 22  NaN  ...   NaN     NaN     NaN       NaN     NaN     NaN       NaN
# 23  NaN  ...   NaN     NaN     NaN       NaN     NaN     NaN       NaN
# 24  NaN  ...   NaN     NaN     NaN       NaN     NaN     NaN       NaN
# 25  NaN  ...   NaN     NaN     NaN       NaN     NaN     NaN       NaN
# 26  NaN  ...   NaN     NaN     NaN       NaN     NaN     NaN       NaN
# 27  NaN  ...   NaN     NaN     NaN       NaN     NaN     NaN       NaN
#
#     mn_130  mw_130   DPI_130
# 0    430.0   665.0  1.546512
# 1    315.0   425.0  1.349206
# 2    437.0   649.0  1.485126
# 3    484.0   828.0  1.710744
# 4    585.0   994.0  1.699145
# 5    495.0   880.0  1.777778
# 6    638.0  1540.0  2.413793
# 7    710.0  1529.0  2.153521
# 8    686.0  1928.0  2.810496
# 9    716.0  2124.0  2.966480
# 10   760.0  1998.0  2.628947
# 11  1007.0  2774.0  2.754717
# 12     NaN     NaN       NaN
# 13     NaN     NaN       NaN
# 14     NaN     NaN       NaN
# 15     NaN     NaN       NaN
# 16     NaN     NaN       NaN
# 17     NaN     NaN       NaN
# 18     NaN     NaN       NaN
# 19     NaN     NaN       NaN
# 20     NaN     NaN       NaN
# 21     NaN     NaN       NaN
# 22     NaN     NaN       NaN
# 23     NaN     NaN       NaN
# 24     NaN     NaN       NaN
# 25     NaN     NaN       NaN
# 26     NaN     NaN       NaN
# 27     NaN     NaN       NaN
#
# [28 rows x 24 columns]
